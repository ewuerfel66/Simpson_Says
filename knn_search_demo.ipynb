# %% [markdown]
# ## Import data, inspect, drop NaN rows

# %%
import pandas as pd
import numpy as np

# %%
lines = pd.read_csv('simpsons_script_lines.csv')
lines.head()
# Out:
# /Users/stephensinclair/.local/share/virtualenvs/simpsonssays-_9L5OZdo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0    id  episode_id  number  \
# 0           0  9549          32     209
# 1           1  9550          32     210
# 2           2  9551          32     211
# 3           3  9552          32     212
# 4           4  9553          32     213
#
#                                             raw_text timestamp_in_ms  \
# 0  Miss Hoover: No, actually, it was a little of ...          848000
# 1  Lisa Simpson: (NEAR TEARS) Where's Mr. Bergstrom?          856000
# 2  Miss Hoover: I don't know. Although I'd sure l...          856000
# 3           Lisa Simpson: That life is worth living.          864000
# 4  Edna Krabappel-Flanders: The polls will be ope...          864000
#
#   speaking_line character_id  location_id       raw_character_text  \
# 0          True          464          3.0              Miss Hoover
# 1          True            9          3.0             Lisa Simpson
# 2          True          464          3.0              Miss Hoover
# 3          True            9          3.0             Lisa Simpson
# 4          True           40          3.0  Edna Krabappel-Flanders
#
#                raw_location_text  \
# 0  Springfield Elementary School
# 1  Springfield Elementary School
# 2  Springfield Elementary School
# 3  Springfield Elementary School
# 4  Springfield Elementary School
#
#                                         spoken_words  \
# 0  No, actually, it was a little of both. Sometim...
# 1                             Where's Mr. Bergstrom?
# 2  I don't know. Although I'd sure like to talk t...
# 3                         That life is worth living.
# 4  The polls will be open from now until the end ...
#
#                                      normalized_text  word_count  \
# 0  no actually it was a little of both sometimes ...        31.0
# 1                                wheres mr bergstrom         3.0
# 2  i dont know although id sure like to talk to h...        22.0
# 3                          that life is worth living         5.0
# 4  the polls will be open from now until the end ...        33.0
#
#                                               lemmas  \
# 0  ['actually', 'little', 'disease', 'magazine', ...
# 1                           ['s', 'mr', 'bergstrom']
# 2  ['not', 'know', 'would', 'sure', 'like', 'talk...
# 3                          ['life', 'worth', 'live']
# 4  ['poll', 'open', 'end', 'recess', 'case', 'dec...
#
#                                        joined_lemmas
# 0  actually little disease magazine news show nat...
# 1                                     s mr bergstrom
# 2  not know would sure like talk not touch lesson...
# 3                                    life worth live
# 4  poll open end recess case decide thought final...

# %%
lines.isnull().sum()
# Out:
# Unnamed: 0                0
# id                        0
# episode_id                0
# number                    0
# raw_text                  0
# timestamp_in_ms           0
# speaking_line             0
# character_id          17521
# location_id             407
# raw_character_text    17522
# raw_location_text       408
# spoken_words          26159
# normalized_text       26184
# word_count            26159
# lemmas                26184
# joined_lemmas         29849
# dtype: int64

# %%
lines.shape
# Out:
# (158248, 16)

# %%
lines = lines.dropna()
lines.isnull().sum()
# Out:
# Unnamed: 0            0
# id                    0
# episode_id            0
# number                0
# raw_text              0
# timestamp_in_ms       0
# speaking_line         0
# character_id          0
# location_id           0
# raw_character_text    0
# raw_location_text     0
# spoken_words          0
# normalized_text       0
# word_count            0
# lemmas                0
# joined_lemmas         0
# dtype: int64

# %%
lines.shape
# Out:
# (128025, 16)

# %% [markdown]
# ## Import spacy, create a list of docs and a list of their vectors

# %%
import spacy

# %%
docs = []
nlp = spacy.load('en_core_web_lg')

# %%
count = 0
for doc in nlp.pipe(lines['joined_lemmas'].values):
    docs.append(doc)

# %%
vectors = [doc.vector for doc in docs]

# %% [markdown]
# ### Add vectors to lines df

# %%
lines['vectors'] = vectors

# %% [markdown]
# ## Initialize a KNN model and fit on the vectors

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nn  = NearestNeighbors(n_neighbors=5, algorithm='ball_tree')
nn.fit(vectors)
# Out:
# NearestNeighbors(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %% [markdown]
# ## Functions to get vectors/find quotes

# %%
def get_vectors_of_string(inp_str):
    lemma_list = get_lemmas(inp_str)
    joined = " ".join(lemma_list)
    return nlp(joined).vector

# %%
def find_quotes(inp_str):
    vect = get_vectors_of_string(inp_str)
    closest_quotes = nn.kneighbors([vect])
    return lines.iloc[closest_quotes[1][0]]

# %% [markdown]
# ## Check if the functions are cromulent

# %%
find_quotes("matter of fact, they're all in the hammock complex")
# Out:
#        Unnamed: 0     id  episode_id  number  \
# 34271       34271  44093         155     199
# 10240       10240  19829          67      67
# 34261       34261  44083         155     189
# 88587       88587  98567         342     174
# 42568       42568  52417         186     102
#
#                                                 raw_text timestamp_in_ms  \
# 34271  Hank Scorpio: That might... Matter of fact, th...          886000
# 10240  Homer Simpson: My hammock! Do you understand? ...          321000
# 34261  Hank Scorpio: (IMPRESSED) Hammocks? My goodnes...          870000
# 88587  Homer Simpson: Well... I'm worried about Marge...          857000
# 42568  Dr. Julius Hibbert: Now, regardless of what th...          483000
#
#       speaking_line character_id  location_id  raw_character_text  \
# 34271          True         2040       1497.0        Hank Scorpio
# 10240          True            2        215.0       Homer Simpson
# 34261          True         2040       1497.0        Hank Scorpio
# 88587          True            2         10.0       Homer Simpson
# 42568          True          332        890.0  Dr. Julius Hibbert
#
#                      raw_location_text  \
# 34271                           GLOBEX
# 10240                   WINFIELD HOUSE
# 34261                           GLOBEX
# 88587  Springfield Nuclear Power Plant
# 42568                Construction Site
#
#                                             spoken_words  \
# 34271  That might... Matter of fact, they're all in t...
# 10240  My hammock! Do you understand? Mine! Don't loo...
# 34261  Hammocks? My goodness, what an idea. Why didn'...
# 88587  Well... I'm worried about Marge and Moe. They'...
# 42568  Now, regardless of what this thing is, it's a ...
#
#                                          normalized_text  word_count  \
# 34271  that might matter of fact theyre all in the sa...        18.0
# 10240  my hammock do you understand mine dont look th...        10.0
# 34261  hammocks my goodness what an idea why didnt i ...        25.0
# 88587  well im worried about marge and moe theyve dev...        28.0
# 42568  now regardless of what this thing is its a pri...        34.0
#
#                                                   lemmas  \
# 34271  ['matter', 'fact', 'complex', 'hammock', 'comp...
# 10240    ['hammock', 'understand', 'not', 'look', 'way']
# 34261  ['hammock', 'goodness', 'idea', 'not', 'think'...
# 88587  ['be', 'worry', 'marge', 'moe', 'have', 'devel...
# 42568  ['regardless', 'thing', 'priceless', 'scientif...
#
#                                            joined_lemmas  \
# 34271                matter fact complex hammock complex
# 10240                    hammock understand not look way
# 34261  hammock goodness idea not think hammock homer ...
# 88587  be worry marge moe have develop intimate bond ...
# 42568  regardless thing priceless scientific find pre...
#
#                                                  vectors
# 34271  [-0.041675992, 0.15653822, 0.06628001, -0.2048...
# 10240  [0.0172494, 0.10171799, -0.285124, -0.10154042...
# 34261  [0.24214274, 0.13538934, -0.10292957, -0.08530...
# 88587  [-0.04170692, 0.102905124, -0.16318122, 0.0177...
# 42568  [-0.17448243, -0.02654165, -0.21030657, 0.1130...

# %%
lines.loc[34275]['spoken_words']
# Out:
# "That might... Matter of fact, they're all in the same complex. It's the Hammock Complex, down on Third?"

# %%
find_quotes("win friends with salad")
# Out:
#         Unnamed: 0      id  episode_id  number  \
# 142612      142612  153067         548      31
# 29948        29948   39671         138     161
# 139617      139617  150066         536     227
# 28558        28558   38280         133     114
# 105387      105387  115494         406      63
#
#                                                  raw_text timestamp_in_ms  \
# 142612    Bart Simpson: That man sure loved potato salad.          149000
# 29948   Lionel Hutz: Well, I didn't win. Here's your p...               0
# 139617  Gary Chalmers: (TURNS TO SKINNER) I'll bet my ...          985000
# 28558   Homer Simpson: But all normal people love meat...          536000
# 105387  Marge Simpson: Why does every kid who stays wi...          287000
#
#        speaking_line character_id  location_id raw_character_text  \
# 142612          true            8        131.0       Bart Simpson
# 29948           True          347       1371.0        Lionel Hutz
# 139617          true         1078          3.0      Gary Chalmers
# 28558           True            2          5.0      Homer Simpson
# 105387          True            1       3328.0      Marge Simpson
#
#                     raw_location_text  \
# 142612    First Church of Springfield
# 29948    Springfield Civic Auditorium
# 139617  Springfield Elementary School
# 28558                    Simpson Home
# 105387           CRUISE SHIP TERMINAL
#
#                                              spoken_words  \
# 142612                  That man sure loved potato salad.
# 29948              Well, I didn't win. Here's your pizza.
# 139617  I'll bet my baloney sandwich that girl's gonna...
# 28558   But all normal people love meat. If I went to ...
# 105387  Why does every kid who stays with us bring "mo...
#
#                                           normalized_text  word_count  \
# 142612                   that man sure loved potato salad         6.0
# 29948                   well i didnt win heres your pizza         7.0
# 139617   ill bet my baloney sandwich that girls gonna win         9.0
# 28558   but all normal people love meat if i went to a...        38.0
# 105387  why does every kid who stays with us bring mom...        23.0
#
#                                                    lemmas  \
# 142612         ['man', 'sure', 'love', 'potato', 'salad']
# 29948                     ['not', 'win', 'here', 'pizza']
# 139617  ['ill', 'bet', 'baloney', 'sandwich', 'girl', ...
# 28558   ['normal', 'people', 'love', 'meat', 'go', 'ba...
# 105387  ['kid', 'stay', 'bring', 'mommy', 'meal', 'pin...
#
#                                             joined_lemmas  \
# 142612                         man sure love potato salad
# 29948                                  not win here pizza
# 139617            ill bet baloney sandwich girl go to win
# 28558   normal people love meat go barbecue meat yo go...
# 105387  kid stay bring mommy meal pineapple potato sal...
#
#                                                   vectors
# 142612  [-0.2112926, 0.2741652, 0.02738459, -0.2130744...
# 29948   [-0.09418982, 0.055107497, -0.042695, -0.04922...
# 139617  [-0.1573825, -0.024347529, 0.0022074897, 0.113...
# 28558   [-0.17415681, 0.027866596, -0.018625999, -0.01...
# 105387  [-0.27995518, 0.17613508, -0.0129324505, -0.08...

# %%
find_quotes("steamed hams")
# Out:
#         Unnamed: 0      id  episode_id  number  \
# 32670        32670   42488         149     114
# 32660        32660   42479         149     105
# 110475      110475  120662         426      68
# 63025        63025   72928         254      98
# 2875          2875   12412          41     263
#
#                                                  raw_text timestamp_in_ms  \
# 32670                  Gary Chalmers: For "steamed hams."          593000
# 32660   Gary Chalmers: You call hamburgers "steamed ha...          566000
# 110475                       Moe Szyslak: Ham sandwiches!          295000
# 63025   Marge Simpson: Do you want turkey sausage or ham?          482000
# 2875    Waitress: That's ham, sausage and bacon with a...         1016000
#
#        speaking_line character_id  location_id raw_character_text  \
# 32670           True         1078        455.0      Gary Chalmers
# 32660           True         1078        455.0      Gary Chalmers
# 110475          True           17       3491.0        Moe Szyslak
# 63025           True            1         48.0      Marge Simpson
# 2875            True          608        481.0           Waitress
#
#             raw_location_text  \
# 32670            Skinner Home
# 32660            Skinner Home
# 110475         LICENSE BUREAU
# 63025   Springfield Town Hall
# 2875              Izzy's Deli
#
#                                              spoken_words  \
# 32670                                 For "steamed hams."
# 32660                 You call hamburgers "steamed hams?"
# 110475                                    Ham sandwiches!
# 63025                  Do you want turkey sausage or ham?
# 2875    That's ham, sausage and bacon with a smidge of...
#
#                                           normalized_text  word_count  \
# 32670                                    for steamed hams         3.0
# 32660                    you call hamburgers steamed hams         5.0
# 110475                                     ham sandwiches         2.0
# 63025                   do you want turkey sausage or ham         7.0
# 2875    thats ham sausage and bacon with a smidge of mayo        10.0
#
#                                                    lemmas  \
# 32670                                  ['steamed', 'ham']
# 32660                       ['hamburger', 'steam', 'ham']
# 110475                                ['ham', 'sandwich']
# 63025                ['want', 'turkey', 'sausage', 'ham']
# 2875    ['s', 'ham', 'sausage', 'bacon', 'smidge', 'ma...
#
#                           joined_lemmas  \
# 32670                       steamed ham
# 32660               hamburger steam ham
# 110475                     ham sandwich
# 63025           want turkey sausage ham
# 2875    s ham sausage bacon smidge mayo
#
#                                                   vectors
# 32670   [-0.425248, -0.457865, 0.3288425, 0.460047, 0....
# 32660   [-0.13849701, -0.14111353, 0.40295032, 0.33257...
# 110475  [-0.353722, -0.42622, 0.651725, 0.635225, 0.19...
# 63025   [-0.4730565, -0.11206575, 0.2597675, 0.4477937...
# 2875    [-0.30809948, -0.021444669, 0.39093003, 0.3375...

# %%
find_quotes("maybe lisa is right that America is the land of opportunity")
# Out:
#         Unnamed: 0     id  episode_id  number  \
# 152015      152015   3255          11     178
# 9266          9266  18878          63     221
# 62557        62557  72465         252     225
# 87112        87112  97090         337      95
# 40260        40260  50101         177     238
#
#                                                  raw_text timestamp_in_ms  \
# 152015  Homer Simpson: Please, please kids. Stop fight...          694000
# 9266    Lisa Simpson: As Little Miss Springfield, it's...         1077000
# 62557   The Rich Texan: Uh-huh. In Texas, we do traged...          992000
# 87112   Apu Nahasapeemapetilon: Oh Mrs. Simpson, you m...          443000
# 40260   Troy McClure: So join America's favorite TV fa...         1324000
#
#        speaking_line character_id  location_id      raw_character_text  \
# 152015          true            2          5.0           Homer Simpson
# 9266            True            9        670.0            Lisa Simpson
# 62557           True         1508         25.0          The Rich Texan
# 87112           True          208        136.0  Apu Nahasapeemapetilon
# 40260           True          426       1636.0            Troy McClure
#
#                   raw_location_text  \
# 152015                 Simpson Home
# 9266               SPRINGFIELD DOCK
# 62557           Simpson Living Room
# 87112                   Kwik-E-Mart
# 40260   Museum of TV and Television
#
#                                              spoken_words  \
# 152015  Please, please kids. Stop fighting. Maybe Lisa...
# 9266    As Little Miss Springfield, it's my pleasure t...
# 62557   Uh-huh. In Texas, we do tragedy right. That's ...
# 87112   Oh Mrs. Simpson, you must pursue your dreams. ...
# 40260   So join America's favorite TV family... and a ...
#
#                                           normalized_text  word_count  \
# 152015  please please kids stop fighting maybe lisas r...        34.0
# 9266    as little miss springfield its my pleasure to ...        16.0
# 62557   uh-huh in texas we do tragedy right thats why ...        27.0
# 87112   oh mrs simpson you must pursue your dreams lik...        35.0
# 40260   so join americas favorite tv family and a tiny...        27.0
#
#                                                    lemmas  \
# 152015  ['kid', 'stop', 'fight', 'maybe', 'lisa', 'rig...
# 9266    ['little', 'miss', 'springfield', 'pleasure', ...
# 62557   ['uh', 'huh', 'texas', 'tragedy', 'right', 's'...
# 87112   ['oh', 'mrs', 'simpson', 'pursue', 'dream', 'l...
# 40260   ['join', 'america', 'favorite', 'tv', 'family'...
#
#                                             joined_lemmas  \
# 152015  kid stop fight maybe lisa right america land o...
# 9266    little miss springfield pleasure welcome ameri...
# 62557   uh huh texas tragedy right s memory poor littl...
# 87112   oh mrs simpson pursue dream like old dream com...
# 40260   join america favorite tv family tiny green spa...
#
#                                                   vectors
# 152015  [-0.242601, 0.1560978, -0.0654051, 0.004721159...
# 9266    [-0.066171385, 0.1839, -0.16130738, -0.0113474...
# 62557   [-0.11148514, 0.15672927, -0.07756445, -0.0282...
# 87112   [0.037973415, 0.09380421, -0.043061897, -0.113...
# 40260   [0.044942755, 0.017361527, -0.11628673, 0.0002...

# %%
lines.loc[152056]['spoken_words']
# Out:
# "Please, please kids. Stop fighting. Maybe Lisa's right about America being a land of opportunity, and maybe Adil has a point about the machinery of capitalism being oiled with the blood of the workers."

# %%
find_quotes('and this is the snack holder where i can put my beverage or cupcake')
# Out:
#         Unnamed: 0      id  episode_id  number  \
# 11546        11546   21142          71     169
# 157139      157139    8445          28     306
# 137906      137906  148334         530     100
# 136266      136266  146695         524     130
# 157137      157137    8443          28     304
#
#                                                  raw_text timestamp_in_ms  \
# 11546   Homer Simpson: And this is the snack holder wh...          770000
# 157139  Head Engineer: (COWED) Extremely large beverag...         1041000
# 137906  Marge Simpson: I thought I was buying snack ca...          477000
# 136266  Lunchlady Dora: Him?! All he takes are sodas a...          681000
# 157137  Head Engineer: Sir, the car has a beverage hol...         1029000
#
#        speaking_line character_id  location_id raw_character_text  \
# 11546           True            2        743.0      Homer Simpson
# 157139          true          420        340.0      Head Engineer
# 137906          true            1          5.0      Marge Simpson
# 136266          true         4715          3.0     Lunchlady Dora
# 157137          true          420        340.0      Head Engineer
#
#                            raw_location_text  \
# 11546                       Monorail Cockpit
# 157139  Powell Motors Corporate Headquarters
# 137906                          Simpson Home
# 136266         Springfield Elementary School
# 157137  Powell Motors Corporate Headquarters
#
#                                              spoken_words  \
# 11546   And this is the snack holder where I can put m...
# 157139                   Extremely large beverage holder.
# 137906                I thought I was buying snack cakes!
# 136266         Him?! All he takes are sodas and desserts!
# 157137                Sir, the car has a beverage holder.
#
#                                           normalized_text  word_count  \
# 11546   and this is the snack holder where i can put m...        19.0
# 157139                    extremely large beverage holder         4.0
# 137906                 i thought i was buying snack cakes         7.0
# 136266            him all he takes are sodas and desserts         8.0
# 157137                  sir the car has a beverage holder         7.0
#
#                                               lemmas  \
# 11546     ['snack', 'holder', 'beverage', 'cupcake']
# 157139  ['extremely', 'large', 'beverage', 'holder']
# 137906             ['think', 'buy', 'snack', 'cake']
# 136266                   ['take', 'soda', 'dessert']
# 157137          ['sir', 'car', 'beverage', 'holder']
#
#                           joined_lemmas  \
# 11546     snack holder beverage cupcake
# 157139  extremely large beverage holder
# 137906             think buy snack cake
# 136266                take soda dessert
# 157137          sir car beverage holder
#
#                                                   vectors
# 11546   [0.289251, -0.23025802, 0.3376525, -0.07969624...
# 157139  [-0.138504, -0.09092925, 0.004502997, -0.03402...
# 137906  [0.015032997, 0.061175875, 0.106795, -0.203697...
# 136266  [-0.031605, 0.07468366, 0.21922666, -0.2043966...
# 157137  [-0.012304001, -0.010795996, 0.0131974965, -0....

# %% [markdown]
# ## Lemmatization with Spacy

# %%
# function to get a list of lemmas from a string
def get_lemmas(text):
    
    if(isinstance(text, float)): #return NaN for NaN values
        return np.nan
    
    else:
        lemmas = []
        doc = nlp(text.lower())
    
        for token in doc:
            if (token.is_stop == False and token.is_punct == False) and token.pos_ != "-PRON-":
                lemmas.append(token.lemma_)
        return lemmas

# %%
df['lemmas'] = df['normalized_text'].apply(get_lemmas)

# %%
def join_lists(x):
    if(isinstance(x, float)): #return NaN for NaN values
        return np.nan
    
    else:
        return " ".join(x)

# %%
df['joined_lemmas'] = df['lemmas'].apply(join_lists)

# %%
df.to_csv('simpsons_script_lines.csv')

# %% [markdown]
# ## Pickle the model

# %%
import joblib

# %%
# save the model to disk
filename = 'knn_model.sav'
joblib.dump(nn, filename)
# Out:
# ['knn_model.sav']

# %%
# save the model to disk
pickle_filename = 'knn_pickled.sav'
pickle.dump(nn, open(pickle_filename, 'wb'))

# %% [markdown]
# Test

# %%
import pickle
import spacy
import pandas as pd

# %%
# Load Search Model
knn_search_file = open('knn_pickled.sav', 'rb')
knn_search = pickle.load(knn_search_file)

# Load Spacy Model
nlp = spacy.load('en_core_web_md')

# Import Data
lines = pd.read_csv('simpsons_script_lines.csv')
lines = lines.dropna()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# function to get a list of lemmas from a string
def get_lemmas(text):
    if(isinstance(text, float)): #return NaN for NaN values
        return np.nan
    else:
        lemmas = []
        doc = nlp(text.lower())
    
        for token in doc:
            if (token.is_stop == False and token.is_punct == False) and token.pos_ != "-PRON-":
                lemmas.append(token.lemma_)
        return lemmas
    
# Get Vectors Function
def get_vectors_of_string(inp_str):
    lemma_list = get_lemmas(inp_str)
    joined = " ".join(lemma_list)
    return nlp(joined).vector

# Find Quotes Function
def find_quotes(inp_str):
    vect = get_vectors_of_string(inp_str)
    closest_quotes = knn_search.kneighbors([vect])
    return (lines['raw_character_text'].iloc[closest_quotes[1][0]], lines['spoken_words'].iloc[closest_quotes[1][0]])

# %%
# Find Quotes Function
def find_quotes(inp_str):
    vect = get_vectors_of_string(inp_str)
    closest_quotes = knn_search.kneighbors([vect])
    indices = closest_quotes[1][0].tolist()
    results = [(lines['raw_character_text'].iloc[i], lines['spoken_words'].iloc[i]) for i in indices]
    return results

# %%
search_results = find_quotes("steamed ham")

# %%
search_results
# Out:
# [('Gary Chalmers', 'You call hamburgers "steamed hams?"'),
#  ('Seymour Skinner',
#   'No, no. I said "steamed hams." That\'s what I call hamburgers.'),
#  ('Seymour Skinner',
#   "Ah... oh, that isn't smoke. It's steam. Steam from the steamed clams we're having. Mmmm, steamed clams."),
#  ('Homer Simpson', 'Steamed Maine cabbages!'),
#  ('Gary Chalmers',
#   'Well, Seymour, you are an odd fellow, but I must say -- you "steam a good ham."')]

# %%
output = {'one': search_results[0],
          'two': search_results[1],
          'three': search_results[2],
          'four': search_results[3],
          'five': search_results[4]}

# %%
output
# Out:
# {'one': ('Gary Chalmers', 'You call hamburgers "steamed hams?"'),
#  'two': ('Seymour Skinner',
#   'No, no. I said "steamed hams." That\'s what I call hamburgers.'),
#  'three': ('Seymour Skinner',
#   "Ah... oh, that isn't smoke. It's steam. Steam from the steamed clams we're having. Mmmm, steamed clams."),
#  'four': ('Homer Simpson', 'Steamed Maine cabbages!'),
#  'five': ('Gary Chalmers',
#   'Well, Seymour, you are an odd fellow, but I must say -- you "steam a good ham."')}

# %%
type(search_results)
# Out:
# list
